# %%
import os
import json
import glob
import collections
import random


from stable_baselines3.common import results_plotter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm


plt.rc('pdf',fonttype = 42)
plt.rc('ps',fonttype = 42)
# Out:
# 2023-08-08 21:47:57.176329: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-08 21:47:57.236283: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-08 21:47:58.170321: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
SMALL_SIZE = 25
MEDIUM_SIZE = 30
BIGGER_SIZE = 40
LINEWIDTH = 5


OURS = "Deconfounded"
NAIVEBC = "Naive BC"
ORACLE = "Oracle"
DAGGER = "DAgger"
TRUE_INTERVENTIONAL = "True interventional"
TRUE_CONDITIONAL = "True conditional"
EXPERT = 'Expert'
GAIL = "GAIL"

# From https://colorbrewer2.org/#type=qualitative&scheme=Set1&n=5
colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00']
r = lambda: random.randint(0,255)
L2C = collections.defaultdict(lambda : f"#{r():02x}{r():02x}{r():02x}")


L2C.update({
    OURS: '#e41a1c',
#     NAIVEBC: '#377eb8',
    NAIVEBC: "#75c1ff",
    ORACLE: 'black',
    DAGGER: 'grey',
    TRUE_INTERVENTIONAL: 'black',
    TRUE_CONDITIONAL: 'black',
    EXPERT: 'black',
    GAIL: 'orange',
})
styles = ["-", "--", "-.", ":", "-"]
rs = lambda: random.randint(0,len(styles)-1)
L2LS = collections.defaultdict(lambda: styles[rs()])
L2LS.update({
    OURS: "solid",
    NAIVEBC: "solid",
    ORACLE: 'solid',
    DAGGER: 'dashed',
    TRUE_INTERVENTIONAL: 'dashed',
    TRUE_CONDITIONAL: 'dashdot',
    EXPERT: 'solid',
    GAIL: 'dashdot',
})


plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('lines', linewidth=LINEWIDTH)

# %%
expdirs = [
    '/data/sun/risrio/dil/logs/20230512_lunar_lander_dil',
    '/data/sun/risrio/dil/logs/20230512_lunar_lander_dagger',
    '/data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle',
    '/data/sun/risrio/dil/logs/20230807_gail_lunar_lander_more_rl_samples',
]

# %%
train_dfs = []
eval_dfs = []
rl_dfs = []
for ed in expdirs:
    logdirs = glob.glob(os.path.join(ed, "**", "args.json"), recursive=True)
    for ld in logdirs:
        with open(ld, "r") as f:
            args = json.load(f)
        label = ""
        if args.get("deconfounding"):
            label = OURS
        elif args.get("dagger"):
            label = DAGGER
        elif "disc_lr" in args:
            label = "GAIL"
            if "permutation" in args["imitator_feature_extractor_obs_keys"]:
                label += " ORACLE"
        elif "permutation" in args["imitator_feature_extractor_obs_keys"]:
            label = ORACLE
        else:
            label = NAIVEBC

        dirname = os.path.dirname(ld)
        try:
            train_df = pd.read_csv(os.path.join(dirname, "train", "progress.csv"))
        except:
            print(f"couldn't load train {dirname}")
        for k, v in args.items():
            train_df[k] = str(v)
        train_df["label"] = label
        train_dfs.append(train_df)
        try:
            eval_df = pd.read_csv(os.path.join(dirname, "eval", "progress.csv"))
            eval_df["label"] = label
            for k, v in args.items():
                eval_df[k] = str(v)
            eval_dfs.append(eval_df)
        except:
            print(f"couldn't load {dirname}")
        try:
            rl_df = pd.read_csv(os.path.join(dirname, "rlalgo", "progress.csv"))
            rl_df["label"] = label
            for k, v in args.items():
                rl_df[k] = str(v)
            rl_dfs.append(rl_df)
        except:
            print(f"couldn't load {dirname}")

try:
    train_df = pd.concat(train_dfs)
except:
    print("no train")
try:
    eval_df = pd.concat(eval_dfs)
except:
    print("no eval")
try:
    rl_df = pd.concat(rl_dfs)
except:
    print("no rl")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dil/trainable_2023-05-12_11-50-59/trainable_45a4a_00002_2_seed=13355_2023-05-12_11-51-08
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dil/trainable_2023-05-12_11-50-59/trainable_45a4a_00001_1_seed=4127479_2023-05-12_11-51-08
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dil/trainable_2023-05-12_11-50-59/trainable_45a4a_00000_0_seed=2342348_2023-05-12_11-51-03
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dil/trainable_2023-05-12_11-50-59/trainable_45a4a_00003_3_seed=423426_2023-05-12_11-51-08
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dil/trainable_2023-05-12_11-50-59/trainable_45a4a_00004_4_seed=99955_2023-05-12_11-51-08
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dagger/20230512_lunar_lander_dagger/trainable_2023-05-12_12-39-50/trainable_18a62_00003_3_seed=423426_2023-05-12_14-27-48
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dagger/20230512_lunar_lander_dagger/trainable_2023-05-12_12-39-50/trainable_18a62_00002_2_seed=13355_2023-05-12_12-40-05
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dagger/20230512_lunar_lander_dagger/trainable_2023-05-12_12-39-50/trainable_18a62_00001_1_seed=4127479_2023-05-12_12-40-00
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dagger/20230512_lunar_lander_dagger/trainable_2023-05-12_12-39-50/trainable_18a62_00000_0_seed=2342348_2023-05-12_12-39-54
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_dagger/20230512_lunar_lander_dagger/trainable_2023-05-12_12-39-50/trainable_18a62_00004_4_seed=99955_2023-05-12_14-27-49
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00008_8_imitator_feature_extractor_obs_keys=obs,seed=99955_2023-05-12_14-39-23
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00001_1_imitator_feature_extractor_obs_keys=obs_permutation,seed=2342348_2023-05-12_11-38-40
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00002_2_imitator_feature_extractor_obs_keys=obs,seed=4127479_2023-05-12_11-38-40
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00005_5_imitator_feature_extractor_obs_keys=obs_permutation,seed=13355_2023-05-12_13-06-31
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00007_7_imitator_feature_extractor_obs_keys=obs_permutation,seed=423426_2023-05-12_14-38-45
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00006_6_imitator_feature_extractor_obs_keys=obs,seed=423426_2023-05-12_14-38-42
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00004_4_imitator_feature_extractor_obs_keys=obs,seed=13355_2023-05-12_13-06-27
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00003_3_imitator_feature_extractor_obs_keys=obs_permutation,seed=4127479_2023-05-12_13-05-22
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00000_0_imitator_feature_extractor_obs_keys=obs,seed=2342348_2023-05-12_11-38-36
# couldn't load /data/sun/risrio/dil/logs/20230512_lunar_lander_bc_naive_and_oracle/20230512_lunar_lander_bc_naive_and_oracle/trainable_2023-05-12_11-38-32/trainable_884ef_00009_9_imitator_feature_extractor_obs_keys=obs_permutation,seed=99955_2023-05-12_16-04-10

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10,))
col = 'bc/rewards'
x = 'train/step'
window = 5

legend_items, legend_labels = [], []


data = eval_df

for label in sorted(data.label.unique()):
    df = data[data.label == label]
    df = df[df[col].isna() == False]
    df[x] = df.index
    mean = df[df.label == label][[col, x, 'seed']].groupby(['seed']).rolling(window, min_periods=1).mean().groupby([x]).mean().reset_index()
    n_seeds = len(df.seed.unique())
    st_mean = df[df.label == label][[col, x, 'seed']].groupby(['seed']).rolling(window, min_periods=1).mean().groupby([x]).mean().reset_index()
    st_err  = df[df.label == label][[col, x, 'seed']].groupby([x]).std().rolling(window).mean().reset_index() / np.sqrt(n_seeds)
    line = ax.plot(mean[x].tolist(), mean[col], label=label, color=L2C[label], linestyle=L2LS[label])
    low = st_mean[col] - st_err[col]
    high = st_mean[col] + st_err[col]
    ax.fill_between(st_mean[x].tolist(), low, high, alpha=0.2, color=L2C[label])
    proxy = ax.fill(np.NaN, np.NaN, c=L2C[label], alpha=0.2, linewidth=0.0)
    legend_items.append((line[0], proxy[0]))
    legend_labels.append(label)

ax.set_xlabel("Training iterations")
ax.set_ylabel("Episode return")
# ax.set_xlim([0, 0])
_ = ax.legend(legend_items, legend_labels, handlelength=3, fontsize=MEDIUM_SIZE+5)
plt.tight_layout()
plt.savefig('lunar_lander_episode_reward_with_gail.pdf', format='pdf')
